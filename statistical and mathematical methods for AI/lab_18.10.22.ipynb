# %%
import numpy as np
import matplotlib.pyplot as plt

# implement GD with following parameters
def GD(f, grad_f, x0, tolf, tolx, kmax):
    # as output we want: 
    # x --> the stationary point 
    # f_val -->  vector with values of f in every iteration
    # err_val --> vectot with values of || grad f(x_k) ||

    k = 0
    x0 = 0
    x = np.zeros((kmax+1,))
    f_val = np.zeros((kmax+1, ))
    grads = np.zeros((kmax+1, ))
    err = np.zeros((kmax+1, ))
    
    conditions = 
    while (conditions)




    return x, k, f_val, grads, err
def f(x):
    return x**2 + 2*x + 1

def grad_f(x):
    return 2*x + 2

GD(f, grad_f, 0, 0.01, 0.01, 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\s0000923424\Desktop\lab_18.10.22.ipynb Cell 1 in <cell line: 46>()
#      <a href='vscode-notebook-cell:/c%3A/Users/s0000923424/Desktop/lab_18.10.22.ipynb#W0sZmlsZQ%3D%3D?line=42'>43</a> def grad_f(x):
#      <a href='vscode-notebook-cell:/c%3A/Users/s0000923424/Desktop/lab_18.10.22.ipynb#W0sZmlsZQ%3D%3D?line=43'>44</a>     return 2*x + 2
# ---> <a href='vscode-notebook-cell:/c%3A/Users/s0000923424/Desktop/lab_18.10.22.ipynb#W0sZmlsZQ%3D%3D?line=45'>46</a> GD(f, grad_f, 0, 0.01, 0.01, 100)
#
# c:\Users\s0000923424\Desktop\lab_18.10.22.ipynb Cell 1 in GD(f, grad_f, x0, tolf, tolx, kmax)
#      <a href='vscode-notebook-cell:/c%3A/Users/s0000923424/Desktop/lab_18.10.22.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a> f_val[k] = f(x[k])
# ...

# %%
def backtracking(f, grad_f, x):
    """
    This function is a simple implementation of the backtracking algorithm for
    the GD (Gradient Descent) method.
    
    f: function. The function that we want to optimize.
    grad_f: function. The gradient of f(x).
    x: ndarray. The actual iterate x_k.
    """
    alpha = 1
    c = 0.8
    tau = 0.25
    
    while f(x - alpha * grad_f(x)) > f(x) - c * alpha * np.linalg.norm(grad_f(x), 2) ** 2:
        alpha = tau * alpha
        
        if alpha < 1e-3:
            break
    return alpha

# %%
def f(x1, x2):
    return 2*x1**2 + (x2 - 2 ) **2

xv = np.linspace(-3,3, 30)
yv = np.linspace(-3,3, 30)

xx, yy = np.meshgrid(xv, yv)

zz = f(xx, yy)


x = np.array([[-2,1], [0,1], [0,2]])

plt.figure()
plt.contour(xx, yy, zz)
plt.plot(x[:, 0], x[:, 1], '-o')
plt.grid()
plt.xlabel("x1")
plt.ylabel("x2")
# Out:
# Text(0, 0.5, 'x2')

# %%
from tkinter import W


def l(w, d):
    #loss function over d
    pass #does nothing you'll have to implementi it

def grad_l(w, d):
    pass

def SGD(l, grad_l, w0, D, batch_size, n_epochs, tolf, tolx, kmax):
    # D is a dataset with a tuple (X, Y) -> X is dxN, Y is N
    X, Y = D
    d, N = X.shape
    n_bach_per_epoch = ...
    alpha = 1
    k = 0
    for epoch in range(n_epochs):
        for x in range(n_bach_per_epoch):
            Mx <- X #the batch from X, has sgaoe d x batch size
            My <- Y  # has shape batch size
    #remove Mx and My from X and Y
            X = ...
            Y = ...
            M = (Mx, My)
            w = w0 - ...
            w0 = W
        X = X_backup
        Y = Y_backup
    # reshuffle every time 
    return w


#remember : in SGD, w0 should be chosen randomly ( sampl from gaussian)
#upgrade : return f_val( over M ) = f_val(k) = l(w_k, M)
#you can have a non monoton of the function
